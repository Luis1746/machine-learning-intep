# %%
# El problema que abordaremos es el abandono de clientes, conocido como churn.
problem_description = "Abandono de clientes (Churn)"
# El problema que abordaremos es el abandono de clientes, conocido como churn.
problem_description = "Abandono de clientes (Churn)"
print(problem_description)
print("Trabajamos con una empresa de telecomunicaciones que quiere predecir cuáles clientes van a abandonar el servicio (Churn) para poder tomar acciones preventivas.")
print("* Conseguir un cliente nuevo representa entre 5x y 25x más que retener uno existente.")

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split  #Dividir los datos en entrenamiento y prueba
from
